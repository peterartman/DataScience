# %%
import requests
import json

# %%
url = "https://www.quandl.com/api/v3/datasets/"  # Replace with your actual URL
response = requests.get(url)
if response.status_code == 200:
    # The request was successful
    print("Request successful")
else:
    # Handle any errors
    print("Request failed:", response.status_code)
# Out:
# Request successful

# %%
type(response)
# Out:
# requests.models.Response

# %%
data = response.json()

# %%
type(data)
# Out:
# dict

# %%
json_data = json.dumps(data)

# %%
print(json_data)
# Out:
# {"datasets": [{"id": 9487650, "dataset_code": "BOM504991", "database_code": "BSE", "name": "VIDARBHA IRON & STEEL CORPORATION LTD. EOD Prices", "description": "End of Day prices and additional trading information for VIDARBHA IRON & STEEL CORPORATION LTD. EOD Prices.", "refreshed_at": "2023-09-01T14:24:51.793Z", "newest_available_date": "2099-12-27", "oldest_available_date": "1991-01-03", "column_names": ["Date", "Open", "High", "Low", "Close", "WAP", "No. of Shares", "No. of Trades", "Total Turnover", "Deliverable Quantity", "% Deli. Qty to Traded Qty", "Spread H-L", "Spread C-O"], "frequency": "weekly", "type": "Time Series", "premium": false, "database_id": 3287}, {"id": 11273261, "dataset_code": "BOM511128", "database_code": "BSE", "name": "GALAXY CONSOLIDATED FINANCE LTD. EOD Prices", "description": "End of Day prices and additional trading information for GALAXY CONSOLIDATED FINANCE LTD. EOD Prices.", "refreshed_at": "2023-09-01T14:24:58.113Z", "newest_available_date": "2099-12-24", "oldest_available_date": "1995-09-14", "column_names": ["Date", "Open", "High", "Low", "Close", "WAP", "No. of Shares", "No. of Trades", "Total Turnover", "Deliverable Quantity", "% Deli. Qty to Traded Qty", "Spread H-L", "Spread C-O"], "frequency": "daily", "type": "Time Series", "premium": false, "database_id": 3287}, {"id": 9488714, "dataset_code": "BOM512415", "database_code": "BSE", "name": "MERCURY TRADE LINKS LTD. EOD Prices", "description": "End of Day prices and additional trading information for MERCURY TRADE LINKS LTD. EOD Prices.", "refreshed_at": "2023-09-01T14:25:00.484Z", "newest_available_date": "2099-12-16", "oldest_available_date": "1992-01-22", "column_names": ["Date", "Open", "High", "Low", "Close", "WAP", "No. of Shares", "No. of Trades", "Total Turnover", "Deliverable Quantity", "% Deli. Qty to Traded Qty", "Spread H-L", "Spread C-O"], "frequency": "daily", "type": "Time Series", "premium": false, "database_id": 3287}, {"id": 11274664, "dataset_code": "BOM531743", "database_code": "BSE", "name": "HIRA AUTOMOBILES LTD. EOD Prices", "description": "End of Day prices and additional trading information for HIRA AUTOMOBILES LTD. EOD Prices.", "refreshed_at": "2023-09-01T14:25:27.724Z", "newest_available_date": "2099-11-30", "oldest_available_date": "1996-07-17", "column_names": ["Date", "Open", "High", "Low", "Close", "WAP", "No. of Shares", "No. of Trades", "Total Turnover", "Deliverable Quantity", "% Deli. Qty to Traded Qty", "Spread H-L", "Spread C-O"], "frequency": "daily", "type": "Time Series", "premium": false, "database_id": 3287}, {"id": 11274657, "dataset_code": "BOM531724", "database_code": "BSE", "name": "HRB FLORICULTURE LTD. EOD Prices", "description": "End of Day prices and additional trading information for HRB FLORICULTURE LTD. EOD Prices.", "refreshed_at": "2023-09-01T14:25:27.724Z", "newest_available_date": "2099-11-26", "oldest_available_date": "1996-06-11", "column_names": ["Date", "Open", "High", "Low", "Close", "WAP", "No. of Shares", "No. of Trades", "Total Turnover", "Deliverable Quantity", "% Deli. Qty to Traded Qty", "Spread H-L", "Spread C-O"], "frequency": "daily", "type": "Time Series", "premium": false, "database_id": 3287}, {"id": 9488738, "dataset_code": "BOM512479", "database_code": "BSE", "name": "Virya Resources Ltd EOD Prices", "description": "End of Day prices and additional trading information for Virya Resources Ltd EOD Prices.", "refreshed_at": "2023-09-01T14:25:01.703Z", "newest_available_date": "2099-09-29", "oldest_available_date": "1991-06-12", "column_names": ["Date", "Open", "High", "Low", "Close", "WAP", "No. of Shares", "No. of Trades", "Total Turnover", "Deliverable Quantity", "% Deli. Qty to Traded Qty", "Spread H-L", "Spread C-O"], "frequency": "daily", "type": "Time Series", "premium": false, "database_id": 3287}, {"id": 9487864, "dataset_code": "BOM506196", "database_code": "BSE", "name": "VIKSIT ENGINEERING LTD. EOD Prices", "description": "End of Day prices and additiona ...

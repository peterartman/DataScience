# %%
# example from https://medium.com/@koki_noda/how-to-use-oecd-data-in-python-69a0234c6b27
# other examle (not used in this code) https://medium.com/@akshaybagal/oecd-stats-website-your-go-to-for-comprehensive-statistics-datasets-on-oecd-countries-2ae04e4aa044

import pandas as pd
import datetime as dt
import pandas_datareader.data as web

# %%
start_time = dt.datetime(1950, 1, 1)
end_time = dt.datetime(2022, 2, 1)
df = web.DataReader('HISTPOP', 'oecd', start_time, end_time)

# %%
print(df.shape)
df.info()
df.head()
# Out:
# (23, 5208)
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23 entries, 2000-01-01 to 2022-01-01
# Columns: 5208 entries, ('Australia', 'Women', 'Total') to ('European Union (27 countries)', 'Total', 'Old age dependency ratio (65 and over/20-64)')
# dtypes: float64(5208)
# memory usage: 936.0 KB
# Country      Australia                                                    \
# Sex              Women
# Age              Total    0 to 4    5 to 9  10 to 14  15 to 19  20 to 24
# Time
# 2000-01-01   9585337.0  620507.0  653189.0  648099.0  643833.0  630318.0
# 2001-01-01   9712875.0  620632.0  653425.0  655629.0  655832.0  635585.0
# 2002-01-01   9819727.0  618479.0  650643.0  662322.0  661925.0  646892.0
# 2003-01-01   9933140.0  618520.0  647081.0  667589.0  666720.0  663262.0
# 2004-01-01  10036771.0  618674.0  645030.0  671148.0  670030.0  677235.0
#
# Country                                             ...  \
# Sex                                                 ...
# ...

# %%
country = "Poland"
sex = "Total"  # Men and Women
df_japan_total = df[country][sex]
df_japan_total.head()
# Out:
# Age              Total     0 to 4     5 to 9   10 to 14   15 to 19   20 to 24  \
# Time
# 2000-01-01  38258477.5  2016434.0  2484452.0  2937340.0  3338185.0  3105369.0
# 2001-01-01  38248076.0  1952348.0  2374469.0  2840022.0  3329887.0  3137217.0
# 2002-01-01  38232301.0  1884802.0  2271562.0  2758960.0  3274832.0  3164145.0
# 2003-01-01  38195177.0  1841413.0  2175333.0  2674129.0  3168642.0  3232197.0
# 2004-01-01  38180249.0  1808692.0  2087358.0  2583521.0  3043241.0  3287121.0
#
# Age          25 to 29   30 to 34   35 to 39   40 to 44  ...    15 to 64  \
# Time                                                    ...
# 2000-01-01  2727748.0  2396164.0  2579380.0  3120987.0  ...  26135867.0
# 2001-01-01  2821388.0  2421355.0  2500291.0  3019804.0  ...  26312920.0
# 2002-01-01  2904999.0  2468402.0  2438795.0  2895227.0  ...  26455781.0
# 2003-01-01  2972660.0  2538101.0  2400956.0  2762964.0  ...  26592435.0
# ...

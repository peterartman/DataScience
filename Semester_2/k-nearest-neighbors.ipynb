# %% [markdown]
# # k-Nearest Neighbors (kNN)
# This Jupyter notebook summarizes the <a href=#pros>Pros</a> and <a href=#cons>Cons</a> of the k-Nearest Neighbors algorithm and gives two Python examples on usage for <a href=#clas>Classification</a> and <a href=#reg>Regression</a>.
#
# ## Theory<sup>1,2,3</sup>
# * Is a non-probabilistic, non-parametric and instance-based learning algorithm (see <a href=#reference>References</a>:
#     * **Non-parametric** means it makes no explicit assumptions about the function form of _h_, avoiding the dangers of mis-modelling the underlying distribution of the data
#         * For example, suppose our data is highly non-Gaussian but the learning model was choose assumes a Gaussian form. In that case, a parametric algorithm would make extremely poor predictions.
#     * **Instance-based** learning means that the algorithm does not explicitly learn a model
#         * Instead, it chooses to memorize the training instances which are subsequently used as "knowledge" for the prediction phase
#         * Concretely, this means that only when a query to our database is made (i.e., when we ask it to predict a label given an input), will the algorithm use the training instances to predict the result
#
# ### Pros<a name="pros"/>
# * **simple** to understand and implement
# * with **little to zero training time**
# * kNN **works just as easily with multi-class data** sets whereas other algorithms are hard-coded for the binary setting
# * the non-parametric nature of kNN gives it an edge in certain settings where the data may be highly unusual, thus **without prior knowledge on distribution**
#
# ### Cons<a name="cons"/>
# * **computationally expensive** testing phase
#     * we **need to store the whole data set for each decision**!
# * can **suffer from skewed class distributions**
#     * for example, if a certain class is very frequent in the training set, it will tend to dominate the majority voting of the new example (large number = more common)
# * the accuracy can be severally **degraded with high-dimension data** because of the little difference between the nearest and farthest neighbor
#     * **the curse of dimensionality** refers to various phenomena that arise when analyzing and organizing data in high-dimensional spaces that do not occur in low-dimensional settings such as the three-dimensional physical space of everyday experience
#     * for high-dimensional data (e.g., with number of dimensions more than 10) **scaling** and **dimension reductions** (such as PCA) is usually performed prior applying kNN
#
# ### References<a name="reference"/>
# * <sup>1</sup>Wikipedia [kNN](https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm), [Curse of dimensionality](https://en.wikipedia.org/wiki/Curse_of_dimensionality)
# * <sup>2</sup>Sklearn [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html), [KNeighborsRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html)
# * <sup>3</sup>[Complete Guide to K-Nearest-Neighbors](https://kevinzakka.github.io/2016/07/13/k-nearest-neighbor)

# %% [markdown]
# ## Classification<a name="clas"/>
# * the output is a class membership
# * an object is classified by a **majority vote** of its neighbours, with the object being assigned to the class most common among its k nearest neighbours
#     * if k = 1, then the object is simply assigned to the class of that nearest neighbour
#
#
# ### Example: predict [IRIS](https://scikit-learn.org/stable/datasets/index.html#iris-dataset) class

# %% [markdown]
# Set environment

# %%
# Scikit-learn
from sklearn import datasets
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier,KNeighborsRegressor
from sklearn.dummy import DummyClassifier, DummyRegressor
from sklearn.metrics import classification_report, mean_squared_error
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
# other libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Use vector drawing inside jupyter notebook
# %config InlineBackend.figure_format = "svg"
# Set matplotlib default axis font size (inside this notebook)
plt.rcParams.update({'font.size': 8})

# %% [markdown]
# Load data

# %%
iris = datasets.load_iris()
# This is extra step that can be omitted but Pandas DataFrame contains some powerfull features
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df = df.assign(target=iris.target)

# %% [markdown]
# Show data summary: extend the `describe` method by selected stats
# * See the Jupyter notebook on **Standard Procedure** for more details

# %%
# Compute selected stats
dfinfo = pd.DataFrame(df.dtypes,columns=["dtypes"])
for (m,n) in zip([df.count(),df.isna().sum()],["count","isna"]):
    dfinfo = dfinfo.merge(pd.DataFrame(m,columns=[n]),right_index=True,left_index=True,how="inner");
# Add to `describe` output
dfinfo.T.append(df.describe())
# Out:
#        sepal length (cm) sepal width (cm) petal length (cm) petal width (cm)  \
# dtypes           float64          float64           float64          float64
# count                150              150               150              150
# isna                   0                0                 0                0
# count                150              150               150              150
# mean             5.84333          3.05733             3.758          1.19933
# std             0.828066         0.435866            1.7653         0.762238
# min                  4.3                2                 1              0.1
# 25%                  5.1              2.8               1.6              0.3
# 50%                  5.8                3              4.35              1.3
# 75%                  6.4              3.3               5.1              1.8
# max                  7.9              4.4               6.9              2.5
#
#           target
# dtypes     int64
# count        150
# isna           0
# count        150
# mean           1
# std     0.819232
# min            0
# 25%            0
# 50%            1
# 75%            2
# max            2

# %% [markdown]
# Show histogram (distribution)

# %%
plt.figure(figsize=(9,2))
for (i,v) in enumerate(df.columns):
    plt.subplot(1,df.shape[1],i+1);
    plt.hist(df.iloc[:,i],bins="sqrt")
    plt.title(df.columns[i],fontsize=9);

# %% [markdown]
# Show correlation matrix

# %%
df.corr().round(2).style.background_gradient(cmap="viridis")
# Out:
# <style  type="text/css" >
#     #T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col1 {
#             background-color:  #3f4889;
#             color:  #f1f1f1;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col2 {
#             background-color:  #c2df23;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col3 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col4 {
#             background-color:  #98d83e;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col0 {
#             background-color:  #b2dd2d;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col3 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col4 {
#             background-color:  #eae51a;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col0 {
#             background-color:  #93d741;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col1 {
#             background-color:  #471063;
#             color:  #f1f1f1;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col2 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col4 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col0 {
#             background-color:  #7cd250;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col2 {
#             background-color:  #eae51a;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col3 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }</style><table id="T_e07e40c0_83d0_11ea_abf0_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal length (cm)</th>        <th class="col_heading level0 col1" >sepal width (cm)</th>        <th class="col_heading level0 col2" >petal length (cm)</th>        <th class="col_heading level0 col3" >petal width (cm)</th>        <th class="col_heading level0 col4" >target</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e07e40c0_83d0_11ea_abf0_0242ac130202level0_row0" class="row_heading level0 row0" >sepal length (cm)</th>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col1" class="data row0 col1" >-0.12</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col2" class="data row0 col2" >0.87</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col3" class="data row0 col3" >0.82</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row0_col4" class="data row0 col4" >0.78</td>
#             </tr>
#             <tr>
#                         <th id="T_e07e40c0_83d0_11ea_abf0_0242ac130202level0_row1" class="row_heading level0 row1" >sepal width (cm)</th>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col0" class="data row1 col0" >-0.12</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col2" class="data row1 col2" >-0.43</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col3" class="data row1 col3" >-0.37</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row1_col4" class="data row1 col4" >-0.43</td>
#             </tr>
#             <tr>
#                         <th id="T_e07e40c0_83d0_11ea_abf0_0242ac130202level0_row2" class="row_heading level0 row2" >petal length (cm)</th>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col0" class="data row2 col0" >0.87</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col1" class="data row2 col1" >-0.43</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col3" class="data row2 col3" >0.96</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row2_col4" class="data row2 col4" >0.95</td>
#             </tr>
#             <tr>
#                         <th id="T_e07e40c0_83d0_11ea_abf0_0242ac130202level0_row3" class="row_heading level0 row3" >petal width (cm)</th>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col0" class="data row3 col0" >0.82</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col1" class="data row3 col1" >-0.37</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col2" class="data row3 col2" >0.96</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row3_col4" class="data row3 col4" >0.96</td>
#             </tr>
#             <tr>
#                         <th id="T_e07e40c0_83d0_11ea_abf0_0242ac130202level0_row4" class="row_heading level0 row4" >target</th>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col0" class="data row4 col0" >0.78</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col1" class="data row4 col1" >-0.43</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col2" class="data row4 col2" >0.95</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col3" class="data row4 col3" >0.96</td>
#                         <td id="T_e07e40c0_83d0_11ea_abf0_0242ac130202row4_col4" class="data row4 col4" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Scale and try to **reduce dimensions**: what we try to do is to **always simply the model** if possible (see correlation matrix above)
# * More complex model (e.g., more features, or higher _*k*_) will (in theory) increase the probability of higher "out of sample" error (even when "in sample" error = train set) will be smaller!
# * Use either 99% threshold (own subjective) or "mle" algorithm (more objective)
# * Use **linear** scaler (transformation)
# * Here, the data is scaled prior train-test split.
#     * In real applications, first split and scale afterwards, to simulate real-world scenario where we do not have the test set! (otherwise data snooping effect)

# %%
scale = StandardScaler(with_mean=True,with_std=True);
Xo = scale.fit_transform(df.drop(["target"],axis=1).values);

# %%
pca = PCA(n_components=0.99)# or set n_components="mle"
X = pca.fit_transform(Xo)
print("Nr. of features after PCA = {} (input = {})".format(X.shape[1],Xo.shape[1]))
# Out:
# Nr. of features after PCA = 3 (input = 4)

# %% [markdown]
# Prepare for fitting

# %%
# encode target values (is not necessary for IRIS but still:-)
y = LabelEncoder().fit_transform(df["target"].values);
# Split 2/3 to 1/3 train to test respectively
[X_train,X_test,y_train,y_test] = train_test_split(X,y,train_size = 0.67,test_size = 0.33,
                                                   stratify=y,random_state=123);

# %% [markdown]
# #### Find optimal model
# * Considering the small data set (150 samples), find "optimal" k setting it to maximum of 5
#     * Optimal in terms of accuracy
#     * Simple model = higher probability of lower in and out-of sample error

# %%
model = KNeighborsClassifier(algorithm="auto");
parameters = {"n_neighbors":[1,3,5],
              "weights":["uniform","distance"]}
model_optim = GridSearchCV(model, parameters, cv=5,scoring="accuracy");

# %%
model_optim.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_neighbors': [1, 3, 5],
#                          'weights': ['uniform', 'distance']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %% [markdown]
# Show the "optimal" settings for kNN

# %%
model_optim.best_estimator_
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %% [markdown]
# #### Show resulting accuracy

# %%
for (i,x,y) in zip(["Train","Test"],[X_train,X_test],[y_train,y_test]):
    print("Classification kNN",i," report:\n",classification_report(y,model_optim.predict(x)))
# Out:
# Classification kNN Train  report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        34
#            1       1.00      1.00      1.00        33
#            2       1.00      1.00      1.00        33
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# Classification kNN Test  report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.88      0.94        17
#            2       0.89      1.00      0.94        17
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50

# %% [markdown]
# In this case, the precision (accuracy=macro avg precision) is very high.
# Just to show that that is not coincidence compare to "dummy" model (most frequent & uniform distribution)

# %%
for i in ["most_frequent","uniform"]:
    dummy = DummyClassifier(strategy=i).fit(X_train,y_train);
    print("Classification ",i," test report:",classification_report(y_test,dummy.predict(X_test)))
# Out:
# Classification  most_frequent  test report:               precision    recall  f1-score   support
#
#            0       0.32      1.00      0.48        16
#            1       0.00      0.00      0.00        17
#            2       0.00      0.00      0.00        17
#
#     accuracy                           0.32        50
#    macro avg       0.11      0.33      0.16        50
# weighted avg       0.10      0.32      0.16        50
#
# Classification  uniform  test report:               precision    recall  f1-score   support
#
#            0       0.33      0.38      0.35        16
#            1       0.47      0.41      0.44        17
#            2       0.35      0.35      0.35        17
#
#     accuracy                           0.38        50
#    macro avg       0.38      0.38      0.38        50
# weighted avg       0.39      0.38      0.38        50
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Regression<a name="reg"/>
# * Predicts value as the **average of the values** of its k nearest neighbors
#
# ### Example: Predict House price
# * Use Scikit-learn [California Housing](https://scikit-learn.org/stable/datasets/index.html#california-housing-dataset) data set
#     * This is a large data set that allows us to use more complex model
# * Nontheless, try to reduce the number of features: via visual inspection and using PCA

# %% [markdown]
# Load data

# %%
# house = datasets.fetch_california_housing()
# df = pd.DataFrame(house.data,columns=house.feature_names)
# df = df.assign(target=house.target)

# %%
df = pd.read_csv("../input/test-data/california_housing.csv").drop(columns=["Unnamed: 0"],errors='ignore')

# %% [markdown]
# Inspect data: show statistics, histogram and correlation

# %%
# Compute selected stats
dfinfo = pd.DataFrame(df.dtypes,columns=["dtypes"])
for (m,n) in zip([df.count(),df.isna().sum()],["count","isna"]):
    dfinfo = dfinfo.merge(pd.DataFrame(m,columns=[n]),right_index=True,left_index=True,how="inner");
# Add to `describe` output
dfinfo.T.append(df.describe())
# Out:
#          MedInc HouseAge  AveRooms AveBedrms Population  AveOccup Latitude  \
# dtypes  float64  float64   float64   float64    float64   float64  float64
# count     20640    20640     20640     20640      20640     20640    20640
# isna          0        0         0         0          0         0        0
# count     20640    20640     20640     20640      20640     20640    20640
# mean    3.87067  28.6395     5.429   1.09668    1425.48   3.07066  35.6319
# std     1.89982  12.5856   2.47417  0.473911    1132.46    10.386  2.13595
# min      0.4999        1  0.846154  0.333333          3  0.692308    32.54
# 25%      2.5634       18   4.44072   1.00608        787   2.42974    33.93
# 50%      3.5348       29   5.22913   1.04878       1166   2.81812    34.26
# 75%     4.74325       37   6.05238   1.09953       1725   3.28226    37.71
# max     15.0001       52   141.909   34.0667      35682   1243.33    41.95
#
#        Longitude   target
# dtypes   float64  float64
# count      20640    20640
# isna           0        0
# count      20640    20640
# mean     -119.57  2.06856
# std      2.00353  1.15396
# min      -124.35  0.14999
# 25%       -121.8    1.196
# 50%      -118.49    1.797
# 75%      -118.01  2.64725
# max      -114.31  5.00001

# %%
plt.figure(figsize=(9,4))
for (i,v) in enumerate(df.columns):
    plt.subplot(2,5,i+1);
    plt.hist(df.iloc[:,i],50,density=True)
    plt.legend([df.columns[i]],fontsize=6);

# %%
df.corr().round(2).style.background_gradient(cmap="viridis")
# Out:
# <style  type="text/css" >
#     #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col1 {
#             background-color:  #46307e;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col2 {
#             background-color:  #287c8e;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col3 {
#             background-color:  #46075a;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col4 {
#             background-color:  #3d4d8a;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col5 {
#             background-color:  #471063;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col6 {
#             background-color:  #26828e;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col7 {
#             background-color:  #23898e;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row0_col8 {
#             background-color:  #52c569;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col5 {
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col6 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col7 {
#             background-color:  #277e8e;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row1_col8 {
#             background-color:  #3e4989;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col0 {
#             background-color:  #2a788e;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col1 {
#             background-color:  #482979;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col3 {
#             background-color:  #a2da37;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col4 {
#             background-color:  #433d84;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col5 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col6 {
#             background-color:  #1f998a;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col7 {
#             background-color:  #24878e;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row2_col8 {
#             background-color:  #3a538b;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col0 {
#             background-color:  #481467;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col1 {
#             background-color:  #443a83;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col2 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col4 {
#             background-color:  #433d84;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col5 {
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col6 {
#             background-color:  #1f948c;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col7 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row3_col8 {
#             background-color:  #481d6f;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col0 {
#             background-color:  #482677;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col2 {
#             background-color:  #481a6c;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col3 {
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col5 {
#             background-color:  #482071;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col6 {
#             background-color:  #277e8e;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col7 {
#             background-color:  #1f988b;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row4_col8 {
#             background-color:  #482576;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col0 {
#             background-color:  #472c7a;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col1 {
#             background-color:  #3c4f8a;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col2 {
#             background-color:  #472e7c;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col3 {
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col4 {
#             background-color:  #375b8d;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col6 {
#             background-color:  #228b8d;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col7 {
#             background-color:  #228b8d;
#             color:  #000000;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row5_col8 {
#             background-color:  #482576;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row6_col0 {
#             background-color:  #470e61;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row6_col1 {
#             background-color:  #3c4f8a;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row6_col2 {
#             background-color:  #3e4a89;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row6_col3 {
#             background-color:  #46307e;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row6_col4 {
#             background-color:  #46337f;
#             color:  #f1f1f1;
#         }    #T_e256eff0_83d0_11ea_abf0_0242ac130202row6_col5 {
#             background-color:  #46085c;
#             color:  #f1f1f1;

# %% [markdown]
# #### Supervised Reduction
# * Considering the correlation, histogram and the summary table:
#     * Remove/drop "AveOccup" (average house occupancy)

# %%
df = df.drop(["AveOccup"],axis=1)

# %% [markdown]
# Prepare for fitting by scaling data set
# * Here, the data is scaled prior train-test split.
#     * In real applications, first split and scale afterwards, to simulate real-world scenario where we do not have the test set!

# %%
X = StandardScaler().fit_transform(df.drop("target",axis=1).values);
y = df.target.values

# %%
X = PCA(n_components="mle").fit_transform(X)
print("Nr. of features after reduction = {} (input = {})".format(X.shape[1],df.shape[1]))
# Out:
# Nr. of features after reduction = 6 (input = 8)

# %% [markdown]
# #### Fit model

# %%
[X_train,X_test,y_train,y_test] = train_test_split(X,y,train_size=0.67,test_size=0.33,
                                                   random_state=123);

# %%
knn = KNeighborsRegressor();
parameters = {"n_neighbors":[1,3,5,7,9],
              "weights":["uniform","distance"]}
knn_reg = GridSearchCV(knn, parameters, cv=5, scoring="neg_mean_squared_error");

# %%
knn_reg.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=KNeighborsRegressor(algorithm='auto', leaf_size=30,
#                                            metric='minkowski',
#                                            metric_params=None, n_jobs=None,
#                                            n_neighbors=5, p=2,
#                                            weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
knn_reg.best_estimator_
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                     weights='distance')

# %%
print("Regression kNN (test) RMSE \t= {:.0f} *1000$".format(
    100*np.sqrt(mean_squared_error(knn_reg.predict(X_test),y_test))))
# Out:
# Regression kNN (test) RMSE 	= 65 *1000$

# %% [markdown]
# Compare to dummy

# %%
for i in ["mean","median"]:
    dummy = DummyRegressor(strategy=i).fit(X_train,y_train);
    print("Regression ",i,"(test) RMSE \t= {:.0f} *1000$".format(
        100*np.sqrt(mean_squared_error(y_test,dummy.predict(X_test)))))
# Out:
# Regression  mean (test) RMSE 	= 116 *1000$
# Regression  median (test) RMSE 	= 118 *1000$
